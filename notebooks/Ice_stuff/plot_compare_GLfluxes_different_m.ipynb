# %%
"""

Compare the melt resulting from old and new tuning for last 10 years of
OPM026,OPM031,ctrl94,isf94

"""

# %%
import xarray as xr
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import cm
import cartopy
import cartopy.crs as ccrs
import matplotlib as mpl
import cmocean
import glob

# %%
sns.set_context('paper')

# %%
# %matplotlib qt5

# %%
home_path = '/bettik/burgardc/'

# %%
inputpath_mask = home_path+'/DATA/SUMMER_PAPER/interim/ANTARCTICA_IS_MASKS/BedMachine_4km/'
file_isf_orig = xr.open_dataset(inputpath_mask+'BedMachinev2_4km_isf_masks_and_info_and_distance_oneFRIS.nc')
nonnan_Nisf = file_isf_orig['Nisf'].where(np.isfinite(file_isf_orig['front_bot_depth_max']), drop=True).astype(int)
file_isf_nonnan = file_isf_orig.sel(Nisf=nonnan_Nisf)
rignot_isf = file_isf_nonnan.Nisf.where(np.isfinite(file_isf_nonnan['isf_area_rignot']), drop=True)
file_isf = file_isf_nonnan.sel(Nisf=rignot_isf)
    
plot_path='/bettik/burgardc/PLOTS/summer_paper_plots/'

# %%
mod = 'CNRM-CM6-1'
scenario = 'ssp585'

to2300 = False

if scenario == 'historical':
    yystart = 1850
    yyend = 2014
else:
    if to2300:
        yystart = 2015
        yyend = 2300
    else:
        yystart = 2015
        yyend = 2100

# %%
sorted_isf_rignot = [11,69,43,28,12,57,
                     70,44,29,13,58,71,45,30,14,
                     59,72,46,
                     31,
                     15,61,73,47,32,16,48,33,17,62,49,34,18,63,74,
                     50,35,19,64,
                     10,
                     36,20,65,51,37,
                     22,38,52,23,66,53,39,24,
                     67,40,54,75,25,41,
                     26,42,55,68,60,27]

# %% [markdown]
# READ IN GL FLUX

# %%
inputpath_GL = '/bettik/burgardc/DATA/SUMMER_PAPER/processed/GL_FLUX/'

GL_fluxes = xr.open_dataset(inputpath_GL + 'all_GL_fluxes_varying_m.nc')
GL_fluxes_with_2300 = xr.open_dataset(inputpath_GL + 'all_GL_fluxes.nc')

# %%
GL_fluxes_with_2300['flux_Gt_ABUMIP_2300']
# Out:
# <xarray.DataArray 'flux_Gt_ABUMIP_2300' (Nisf: 64)>
# [64 values with dtype=float64]
# Coordinates:
#   * Nisf      (Nisf) int64 10 11 12 13 14 15 16 17 ... 68 69 70 71 72 73 74 75
#     ID_IMBIE  (Nisf) int64 ...

# %% [markdown]
# READ IN CALVING FLUX

# %%
inputpath_caving = '/bettik/burgardc/DATA/SUMMER_PAPER/raw/'
calving_flux = xr.open_dataset(inputpath_caving + 'calving_flux_rignot13.nc')['calving_flux_rignot']

# %% [markdown]
# PLOT

# %%
(GL_fluxes['flux_Gt_ABUMIP_m1'] - GL_fluxes['flux_Gt_ABUMIP']).max()
# Out:
# <xarray.DataArray ()>
# array(80.33)

# %%
regions = ['Weddell','Bellingshausen','Amundsen','Ross','East 1','East 2','Dronning Maud Land']
colors = ['red','orange','gold','mediumturquoise','maroon','magenta','cornflowerblue','grey','yellowgreen']

f = plt.figure()
f.set_size_inches(8.25*2, 8.25*2)

ax={}

leg_hdl = []

i = 0


for kisf in tqdm(sorted_isf_rignot):
    
    ax[i] = f.add_subplot(8,8,i+1)
    
        
    ax[i].axhline(y=GL_fluxes['flux_Gt_ref'].sel(Nisf=kisf), color='orange',alpha=0.5)
    ax[i].axhline(y=GL_fluxes['flux_Gt_ref_m1'].sel(Nisf=kisf), color='limegreen',alpha=0.5)
    ax[i].axhline(y=GL_fluxes['flux_Gt_ref_m3'].sel(Nisf=kisf), color='deepskyblue',alpha=0.5)
    ax[i].axhline(y=GL_fluxes['flux_Gt_ref_m5'].sel(Nisf=kisf), color='gold',alpha=0.5)
    
    #ax[i].axhline(y=calving_flux.sel(Nisf=kisf), color='grey')

    #if kisf == 23:
    #    ax[i].set_title('Tracy Tremenchus')
    #elif kisf == 24:
    #    ax[i].set_title('Conger/Glenzer')
    #elif kisf == 110:
    #    ax[i].set_title('Ekström')
    #else:
    ax[i].set_title(str(file_isf_orig['isf_name'].sel(Nisf=kisf).values))
    #ax[i].set_xlim(0,60)
    #ax[i].axvline(x=30, c='k', linestyle='--')

    i = i+1

#f.legend()
f.subplots_adjust(bottom=0.05, wspace=0.1)

f.tight_layout()
sns.despine()
plt.savefig(plot_path+'GL_flux_only_varying_m.pdf')
# Out:
# libGL error: No matching fbConfigs or visuals found
# libGL error: failed to load driver: swrast
#   0%|          | 0/64 [00:00<?, ?it/s]

# %%
regions = ['Weddell','Bellingshausen','Amundsen','Ross','East 1','East 2','Dronning Maud Land']
colors = ['red','orange','gold','mediumturquoise','maroon','magenta','cornflowerblue','grey','yellowgreen']

f = plt.figure()
f.set_size_inches(8.25*2, 8.25*2)

ax={}

leg_hdl = []

i = 0


for kisf in tqdm(sorted_isf_rignot):
    
    ax[i] = f.add_subplot(8,8,i+1)
    
        
    ax[i].axhline(y=GL_fluxes_with_2300['flux_Gt_ABUMIP_2300'].sel(Nisf=kisf), color='red',alpha=0.8)
    ax[i].axhline(y=GL_fluxes['flux_Gt_ABUMIP_m1'].sel(Nisf=kisf), color='orange',alpha=0.8)
    
    #ax[i].axhline(y=calving_flux.sel(Nisf=kisf), color='grey')

    #if kisf == 23:
    #    ax[i].set_title('Tracy Tremenchus')
    #elif kisf == 24:
    #    ax[i].set_title('Conger/Glenzer')
    #elif kisf == 110:
    #    ax[i].set_title('Ekström')
    #else:
    ax[i].set_title(str(file_isf_orig['isf_name'].sel(Nisf=kisf).values))
    #ax[i].set_xlim(0,60)
    #ax[i].axvline(x=30, c='k', linestyle='--')

    i = i+1

#f.legend()
f.subplots_adjust(bottom=0.05, wspace=0.1)

f.tight_layout()
sns.despine()
plt.savefig(plot_path+'GL_flux_compare_ABUMIPref_2300.pdf')
# Out:
#   0%|          | 0/64 [00:00<?, ?it/s]

# %%
GL_fluxes
# Out:
# <xarray.Dataset>
# Dimensions:            (Nisf: 64)
# Coordinates:
#   * Nisf               (Nisf) int64 10 11 12 13 14 15 16 ... 70 71 72 73 74 75
#     ID_IMBIE           (Nisf) int64 ...
# Data variables:
#     flux_Gt_ref        (Nisf) float64 ...
#     flux_Gt_ref_m1     (Nisf) float64 ...
#     flux_Gt_ref_m3     (Nisf) float64 ...
#     flux_Gt_ref_m5     (Nisf) float64 ...
#     flux_Gt_ABUMIP     (Nisf) float64 ...
#     flux_Gt_ABUMIP_m1  (Nisf) float64 ...
#     flux_Gt_ABUMIP_m3  (Nisf) float64 ...
#     flux_Gt_ABUMIP_m5  (Nisf) float64 ...
